# %%
from sklearn import datasets

# %%
from sklearn import linear_model

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
X, y = housing.data, housing.target

# %%
X.shape
# Out:
# (20640, 8)

# %%
y.shape
# Out:
# (20640,)

# %%
plt.scatter(X[:,0],y)

# %%
plt.scatter(X[:,1], y)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.01)

# %%
l_reg = linear_model.LinearRegression()
model = l_reg.fit(x_train, y_train)

# %%
prediction = model.predict(x_test)

# %%
prediction
# Out:
# array([ 0.75313035,  2.91456949,  1.66622053,  3.14831981,  2.43159413,
#         1.9040182 ,  2.32393784,  2.97320466,  2.27136396,  1.77473176,
#         2.04976862,  1.59587175,  4.15628182,  1.81721614,  1.22091285,
#         1.7938152 ,  2.04037664,  1.60890707,  2.28505125,  1.40154798,
#         2.39588744,  1.58741006,  0.74314924,  1.81940677,  2.13002589,
#         2.30338676,  2.45870089,  3.05532125,  2.33006238,  1.54221551,
#         2.66451843,  3.06454649,  2.24952097,  2.01675942,  1.76454442,
#         1.42199712,  3.04342527,  1.2799233 ,  3.26961334,  2.57982022,
#         1.21773234,  2.28921   ,  1.88229146,  1.9536607 ,  2.78912906,
#         2.35583863,  2.44383537,  1.49449963,  0.78954833,  3.47431349,
#         2.239018  ,  1.94211903,  2.14650123,  0.82682161,  2.33573041,
#         1.87121829,  3.24515157,  1.96821843,  1.81258487,  1.14909148,
#         3.05071556,  2.09196865,  2.67210732,  1.83459117,  2.56786356,
#         0.49416955,  1.44934439,  2.47570621,  2.8324819 ,  1.87396264,
#         1.40916819,  1.01084311,  1.19527096,  0.39473119,  2.90575288,
#         2.24958687,  1.72345201,  2.48610372,  2.23105458,  3.2549965 ,
#         2.35477332,  2.62502574,  1.79644612,  2.9860761 ,  0.76280641,
#         1.12168823,  2.40829358,  2.13018554,  2.47030452,  2.07874315,
#         1.5904715 ,  0.72788577,  1.91413409,  1.80126723,  1.38437465,
#         2.12339896,  3.49026102,  2.93913637,  0.25025439,  1.48001074,
#         1.28871943,  1.13488789, -0.05730503,  2.44548035,  1.83820813,
#         2.05052154,  1.25805495,  1.81999799,  0.87839475,  2.7210614 ,
#         2.47019997,  2.1044406 ,  0.83638537,  1.0359112 ,  1.4133532 ,
#         1.97444917,  5.47595987,  2.52962833,  2.39947714,  1.42135392,
#         1.03809413,  2.45094126,  1.53114524,  2.78147088,  3.13750892,
#         1.45339223,  2.02896336,  0.50656567,  1.70020152,  1.69777927,
#         2.77826938,  0.84325517,  1.8237617 ,  2.39393938,  2.66902667,
#         2.13212177,  2.24741651,  4.10315143,  2.85698847,  6.85536871,
#         2.34681821,  2.72590461,  0.36676925,  2.50432718,  2.56403488,
#         2.14180024,  0.67687729,  2.75031483,  2.69938995,  3.24802279,
#         2.54234382,  1.90732651,  2.15675602,  1.85836089,  2.28132198,
#         2.26319282,  2.55400131,  0.51285462,  1.81961451,  1.77905848,
#         0.8844231 ,  2.89528166,  1.44525715,  1.77000684,  2.74975406,
#         1.18109102,  3.82880981,  1.92734989,  1.7872419 ,  2.04625949,
#         1.19222544,  1.94362669,  2.04644282, -0.10155   ,  1.6196968 ,
#         2.19068736,  0.85302479,  1.47463791,  2.39423802,  1.43880861,
#         2.31501157,  2.18408937,  0.67461324,  2.19217068,  4.88970258,
#         3.77432617,  1.2275213 ,  2.02829123,  2.87609184,  0.66110774,
#         1.8391269 ,  2.18484085,  3.32742604,  0.70844359,  0.79640563,
#         2.23742237,  1.5926869 ,  2.19231886,  1.71201984,  1.18391343,
#         0.48014618,  2.08516667,  1.44079957,  0.41351936,  2.63866023,
#         1.8298416 ,  2.22234891])

# %%
plt.scatter(prediction, y_test)

# %%
print("Accuracy / R^2", l_reg.score(X,y))
# Out:
# Accuracy / R^2 0.6062298241886817

# %%
print("Regresion cofficients: ",l_reg.coef_)
# Out:
# Regresion cofficients:  [ 4.37011583e-01  9.39826777e-03 -1.08565715e-01  6.53388825e-01
#  -4.00194690e-06 -3.76078340e-03 -4.21742421e-01 -4.35231150e-01]

# %%
print("y-intercept: ", l_reg.intercept_)
# Out:
# y-intercept:  -37.01462580630123
