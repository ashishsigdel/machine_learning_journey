# %%
import matplotlib.pyplot as plt

x = [11, 29, 44, 55, 47, 28 ,58, 11, 57, 11, 17, 54, 27, 30, 59, 38, 36, 12, 46, 49, 10 ,34, 24, 42,
 35, 33, 51,14, 45, 22, 30 ,17, 38, 34, 36 ,24, 37, 48, 23, 37, 39, 16, 51, 13, 26, 21, 40, 37,
 59, 44, 80]

plt.boxplot(x, notch=False, vert=True, showmeans = True, whis=2)
plt.title("boxplot", fontsize = 20)

plt.show()
