# %%
import matplotlib.pyplot as plt
import pandas as pd
x = [1, 2, 3, 4]
y = [2, 4, 6, 16]
c = ["r", "b", "g", "y"]
var = pd.Series(x)
print(var)

plt.bar(x,y, color=c)

plt.show()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
